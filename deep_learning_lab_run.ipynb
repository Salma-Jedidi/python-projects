# %% [markdown]
# <a href="https://colab.research.google.com/github/Salma-Jedidi/python-projects/blob/yoga-project/deep_learning_lab_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hello, this is our submission for the project: **

# %% [markdown]
# # *Yoga Class Analysis using Human pose estimation*

# %% [markdown]
# # **Business Understanding**
# ### In this project, we aim to build a yoga pose classification model using a convolutional neural network (CNN).
# ### The model will classify images of people performing various yoga poses.

# %% [markdown]
# ![yoga.jpg](data:image/jpeg;base64,...)

# %%
# !pip install -q tensorflow-model-optimization

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from keras.layers import Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, TensorBoard, ReduceLROnPlateau
import tensorflow_model_optimization as tfmot
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# # Data Requirements & Data Collection

# %%
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Pre-processing of the images**

# %%
"""# Set the paths for the dataset
dataset_path = '/content/drive/MyDrive/yoga_dataset/'
train_dir = dataset_path + 'TRAIN/'
test_dir = dataset_path + 'TEST/'"""

# %%
# Set the paths for the dataset
dataset_path = '/content/drive/MyDrive/YOGA/content/cleaned/DATASET'
train_dir = dataset_path + '/TRAIN/'
test_dir = dataset_path + '/TEST/'

# %%
# Parameters
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
batch_size = 32
epochs = 50
num_classes = 5

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 1084 images belonging to 5 classes.
# Found 466 images belonging to 5 classes.

# %% [markdown]
# This code defines data generators for training and testing an image classification model using Keras. The generators read images from directories, resize them, batch them, and categorize them for use in the model training process.

# %%
# CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(256, (3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# This code defines a Convolutional Neural Network (CNN) model for image classification using Keras. The model consists of several convolutional layers followed by pooling layers, a flatten layer, and fully connected layers with dropout regularization, and ends with a softmax activation function for multiclass classification.

# %% [markdown]
# # **Model training**

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
# Callbacks
"""
def lr_schedule(epoch):
    lr = 0.01
    if epoch > 20:
        lr *= 0.1
    elif epoch > 40:
        lr *= 0.01
    return lr
"""

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

callbacks = [early_stopping, checkpoint, lr_scheduler]

# %%
  # Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.n // batch_size,
    callbacks = [callbacks])
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9743
# Epoch 1: val_loss did not improve from 0.41774
# 33/33 [==============================] - 51s 2s/step - loss: 0.1043 - accuracy: 0.9743 - val_loss: 0.4301 - val_accuracy: 0.8683 - lr: 1.0000e-13
# Epoch 2/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9705
# Epoch 2: val_loss did not improve from 0.41774
# 33/33 [==============================] - 41s 1s/step - loss: 0.1157 - accuracy: 0.9705 - val_loss: 0.4470 - val_accuracy: 0.8616 - lr: 1.0000e-13
# Epoch 3/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9753
# Epoch 3: val_loss did not improve from 0.41774
# 33/33 [==============================] - 40s 1s/step - loss: 0.0993 - accuracy: 0.9753 - val_loss: 0.4322 - val_accuracy: 0.8683 - lr: 1.0000e-13
# Epoch 4/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9753
# Epoch 4: val_loss did not improve from 0.41774
# 33/33 [==============================] - 48s 1s/step - loss: 0.0946 - accuracy: 0.9753 - val_loss: 0.4224 - val_accuracy: 0.8638 - lr: 1.0000e-13
# Epoch 5/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9753
# Epoch 5: val_loss did not improve from 0.41774
# 33/33 [==============================] - 47s 1s/step - loss: 0.1086 - accuracy: 0.9753 - val_loss: 0.4483 - val_accuracy: 0.8616 - lr: 1.0000e-13
# Epoch 6/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.9734
# Epoch 6: val_loss did not improve from 0.41774
# 33/33 [==============================] - 46s 1s/step - loss: 0.1061 - accuracy: 0.9734 - val_loss: 0.4479 - val_accuracy: 0.8638 - lr: 1.0000e-13
# Epoch 7/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9686
# Epoch 7: val_loss did not improve from 0.41774
# 33/33 [==============================] - 48s 1s/step - loss: 0.1158 - accuracy: 0.9686 - val_loss: 0.4195 - val_accuracy: 0.8661 - lr: 1.0000e-13
# Epoch 8/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9696
# Epoch 8: val_loss did not improve from 0.41774
# 33/33 [==============================] - 40s 1s/step - loss: 0.1082 - accuracy: 0.9696 - val_loss: 0.4481 - val_accuracy: 0.8616 - lr: 1.0000e-13
# Epoch 9/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9686
# Epoch 9: val_loss improved from 0.41774 to 0.40303, saving model to best_model.h5
# 33/33 [==============================] - 57s 2s/step - loss: 0.1180 - accuracy: 0.9686 - val_loss: 0.4030 - val_accuracy: 0.8683 - lr: 1.0000e-13
# Epoch 10/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9677
# Epoch 10: val_loss did not improve from 0.40303
# 33/33 [==============================] - 40s 1s/step - loss: 0.1213 - accuracy: 0.9677 - val_loss: 0.4370 - val_accuracy: 0.8661 - lr: 1.0000e-13
# Epoch 11/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9667
# Epoch 11: val_loss did not improve from 0.40303
# 33/33 [==============================] - 47s 1s/step - loss: 0.1111 - accuracy: 0.9667 - val_loss: 0.4421 - val_accuracy: 0.8661 - lr: 1.0000e-13
# Epoch 12/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9639
# Epoch 12: val_loss did not improve from 0.40303
# 33/33 [==============================] - 47s 1s/step - loss: 0.1252 - accuracy: 0.9639 - val_loss: 0.4307 - val_accuracy: 0.8683 - lr: 1.0000e-13
# Epoch 13/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9734
# Epoch 13: val_loss did not improve from 0.40303
# 33/33 [==============================] - 47s 1s/step - loss: 0.1148 - accuracy: 0.9734 - val_loss: 0.4429 - val_accuracy: 0.8661 - lr: 1.0000e-13
# Epoch 14/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9715
# Epoch 14: val_loss did not improve from 0.40303
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000001179769417e-14.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000001518582595e-15.
# 33/33 [==============================] - 47s 1s/step - loss: 0.1084 - accuracy: 0.9715 - val_loss: 0.4394 - val_accuracy: 0.8616 - lr: 1.0000e-14
# Epoch 15/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9667
# Epoch 15: val_loss did not improve from 0.40303
# 33/33 [==============================] - 45s 1s/step - loss: 0.1181 - accuracy: 0.9667 - val_loss: 0.4031 - val_accuracy: 0.8638 - lr: 1.0000e-15
# Epoch 16/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9705
# Epoch 16: val_loss did not improve from 0.40303
# 33/33 [==============================] - 47s 1s/step - loss: 0.1099 - accuracy: 0.9705 - val_loss: 0.4526 - val_accuracy: 0.8594 - lr: 1.0000e-15
# Epoch 17/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9705
# Epoch 17: val_loss did not improve from 0.40303
# 33/33 [==============================] - 41s 1s/step - loss: 0.1111 - accuracy: 0.9705 - val_loss: 0.4338 - val_accuracy: 0.8661 - lr: 1.0000e-15
# Epoch 18/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9696
# Epoch 18: val_loss improved from 0.40303 to 0.39364, saving model to best_model.h5
# 33/33 [==============================] - 57s 2s/step - loss: 0.1191 - accuracy: 0.9696 - val_loss: 0.3936 - val_accuracy: 0.8705 - lr: 1.0000e-15
# Epoch 19/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9753
# Epoch 19: val_loss did not improve from 0.39364
# 33/33 [==============================] - 47s 1s/step - loss: 0.1022 - accuracy: 0.9753 - val_loss: 0.4151 - val_accuracy: 0.8661 - lr: 1.0000e-15
# Epoch 20/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1020 - accuracy: 0.9762
# Epoch 20: val_loss did not improve from 0.39364
# 33/33 [==============================] - 47s 1s/step - loss: 0.1020 - accuracy: 0.9762 - val_loss: 0.4354 - val_accuracy: 0.8683 - lr: 1.0000e-15
# Epoch 21/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9639
# Epoch 21: val_loss did not improve from 0.39364
# 33/33 [==============================] - 47s 1s/step - loss: 0.1159 - accuracy: 0.9639 - val_loss: 0.4177 - val_accuracy: 0.8661 - lr: 1.0000e-15
# Epoch 22/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9706
# Epoch 22: val_loss did not improve from 0.39364
# 33/33 [==============================] - 45s 1s/step - loss: 0.1146 - accuracy: 0.9706 - val_loss: 0.4484 - val_accuracy: 0.8616 - lr: 1.0000e-15
# Epoch 23/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9620
# Epoch 23: val_loss did not improve from 0.39364
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000001095066122e-16.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000830368326e-17.
# 33/33 [==============================] - 46s 1s/step - loss: 0.1193 - accuracy: 0.9620 - val_loss: 0.4349 - val_accuracy: 0.8683 - lr: 1.0000e-16
# Epoch 24/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9678
# Epoch 24: val_loss did not improve from 0.39364
# 33/33 [==============================] - 47s 1s/step - loss: 0.1119 - accuracy: 0.9678 - val_loss: 0.4164 - val_accuracy: 0.8661 - lr: 1.0000e-17
# Epoch 25/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9781
# Epoch 25: val_loss did not improve from 0.39364
# 33/33 [==============================] - 40s 1s/step - loss: 0.1066 - accuracy: 0.9781 - val_loss: 0.4515 - val_accuracy: 0.8616 - lr: 1.0000e-17
# Epoch 26/50
# 33/33 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9705
# Epoch 26: val_loss did not improve from 0.39364
# 33/33 [==============================] - 46s 1s/step - loss: 0.1218 - accuracy: 0.9705 - val_loss: 0.4531 - val_accuracy: 0.8594 - lr: 1.0000e-17
# Epoch 27/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9772
# Epoch 27: val_loss did not improve from 0.39364
# 33/33 [==============================] - 46s 1s/step - loss: 0.0932 - accuracy: 0.9772 - val_loss: 0.4434 - val_accuracy: 0.8638 - lr: 1.0000e-17
# Epoch 28/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9781Restoring model weights from the end of the best epoch: 18.
#
# Epoch 28: val_loss did not improve from 0.39364
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000664932204e-18.
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.000000045813705e-19.
# 33/33 [==============================] - 40s 1s/step - loss: 0.0943 - accuracy: 0.9781 - val_loss: 0.4449 - val_accuracy: 0.8638 - lr: 1.0000e-18
# Epoch 28: early stopping

# %% [markdown]
# The output shows the training progress of a neural network model. The model was trained for 50 epochs, and each epoch shows the training loss, training accuracy, validation loss, and validation accuracy.
#
# The training loss and accuracy show how well the model is performing on the training data, while the validation loss and accuracy show how well the model is generalizing to new data.
#
# After each epoch, the model's weights are saved to "best_model.h5" if the validation loss improved. This way, we can use the saved weights later to make predictions on new data without having to retrain the entire model.
#
# Overall, we can see that the model's accuracy improved significantly over the course of the training, starting at 28.76% and ending at 85.43%. The validation accuracy also improved, from 42.41% to 85.04%. This suggests that the model is learning to generalize well to new data. The validation loss also decreased significantly, indicating that the model is improving in its ability to make accurate predictions.

# %% [markdown]
# # **Model evaluation**

# %%
# Evaluate the model
scores = model.evaluate(test_generator, steps=test_generator.n // batch_size)
print("Test loss:", scores[0])
print("Test accuracy:", scores[1])
# Out:
# 14/14 [==============================] - 13s 880ms/step - loss: 0.4459 - accuracy: 0.8638
# Test loss: 0.4459173083305359
# Test accuracy: 0.8638392686843872

# %% [markdown]
# This result indicates that the model achieved a test accuracy of 90.62% and a test loss of 0.3643. This means that the model performed well in classifying the test data with a high degree of accuracy, and the loss value indicates that the model was able to effectively minimize the difference between the predicted and actual values. However, without more context about the problem being solved and the benchmark for success, it is difficult to determine whether this accuracy and loss value are satisfactory or not.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# The training and validation accuracy values of a neural network were visualized over the epochs. The accuracy values of the training and validation sets are plotted against the number of epochs. The graph shows how model accuracy improves over time during training. In this case, we can see that the accuracy of the training and validation sets increases as the number of epochs increases, indicating that the model is learning to make better predictions.

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# We visualized the curves of the loss of training and the loss of validation of the model over the epochs. The curve for training loss and validation loss are both decreasing, indicating that the model improves as training progresses and of course generalizes the test data.

# %% [markdown]
# #**PREDICTION**

# %%
def predict_yoga_pose(image_path):
    img_size = (150, 150)

    # Load the image
    image = load_img(image_path, target_size=img_size)

    # Convert the image to an array
    image_array = img_to_array(image)
    image_array = image_array / 255.0  # Rescale the image

    # Expand the dimensions of the image array
    image_array = np.expand_dims(image_array, axis=0)

    # Make predictions
    predictions = model.predict(image_array)

    # Decode the predictions to get the class label
    predicted_class = np.argmax(predictions, axis=-1)
    class_labels = list(train_generator.class_indices.keys())
    predicted_label = class_labels[predicted_class[0]]

    return predicted_label

# %% [markdown]
# This code defines a function that takes an image path as input and returns the predicted class label for the image using a pre-trained model. The function loads the image, converts it to a NumPy array, rescales it, and then uses the pre-trained model to make predictions. The predictions are then decoded to obtain the predicted class label, which is returned by the function.

# %%
import tensorflow_model_optimization as tfmot

# Apply quantization to the entire model
quantize_model = tfmot.quantization.keras.quantize_model

# Load the best model
model.load_weights('best_model.h5')

# Quantize the best model
quantized_model = quantize_model(model)

# Save the quantized model
quantized_model.save('quantized_best_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
while True:
    image_path = input("Enter the image path (type 'exit' to quit): ")
    if image_path.lower() == 'exit':
        break
    predicted_label = predict_yoga_pose(image_path)
    print(f"Predicted class for {image_path}: {predicted_label}")
